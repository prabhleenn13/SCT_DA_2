# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.virtual_documents',
#  '3D Objects',
#  'accidents_by_hour.png',
#  'ado',
#  'AppData',
#  'Application Data',
#  'archive (1).zip',
#  'bank-additional-full.csv',
#  'bankmarketingdecisiontree.ipynb',
#  'Contacts',
#  'Cookies',
#  'decision_tree.pdf',
#  'decision_tree.png',
#  'decision_tree_readable',
#  'decision_tree_readable.png',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Global_Superstore2.csv',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{41b38d8a-2517-11f0-a87c-9d1b3518eae4}.TM.blf',
#  'NTUSER.DAT{41b38d8a-2517-11f0-a87c-9d1b3518eae4}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{41b38d8a-2517-11f0-a87c-9d1b3518eae4}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'Population visualization.ipynb',
#  'Population visualization_Prabhleenkaur.ipynb',
#  'POPULATION_ANALYSIS.ipynb',
#  'PrintHood',
#  'PYTHON BEEBI.ipynb',
#  'Rave.dat',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'This PC - Shortcut.lnk',
#  'titanic.ipynb',
#  'titanic_cleaned.csv',
#  'Titanic_EDA.ipynb',
#  'top10_population.png',
#  'Traffic Analysis.ipynb',
#  'train.csv',
#  'Untitled.ipynb',
#  'untitled.py',
#  'Untitled1.ipynb',
#  'untitled1.py',
#  'Untitled2.ipynb',
#  'untitled2.py',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'US_Accidents_Cleaned.csv',
#  'US_Accidents_March23.csv',
#  'Videos',
#  'WPS Cloud Files',
#  'WPSDrive']

# %%
import pandas as pd

df = pd.read_csv("Global_Superstore2.csv", encoding="latin1")

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 9.4+ MB

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df[['Order Date', 'Ship Date']].dtypes
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
df.to_csv('Global_Superstore_Cleaned.csv', index=False)

# %%
import os
'Global_Superstore_Cleaned.csv' in os.listdir()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Postal Code'] = df['Postal Code'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
df.to_csv('Global_Superstore_Cleaned.csv', index=False)

# %%
import os
'Global_Superstore_Cleaned.csv' in os.listdir()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df.shape
df.describe()
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64

# %%
print("Total Sales:", df['Sales'].sum())
# Out:
# Total Sales: 12642501.909880001

# %%
print("Total Profit:", df['Profit'].sum())
# Out:
# Total Profit: 1467457.29128

# %%
print("Total Orders:", df['Order ID'].nunique())
# Out:
# Total Orders: 25035

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title('Sales by Category')
plt.ylabel('Sales')
plt.show()

# %%
top_countries = df.groupby('Country')['Sales'].sum().sort_values(ascending=False).head(10)

top_countries.plot(kind='bar')
plt.title('Top 10 Countries by Sales')
plt.ylabel('Sales')
plt.show()

# %%
profit_category = df.groupby('Category')['Profit'].sum()

profit_category.plot(kind='bar')
plt.title('Profit by Category')
plt.ylabel('Profit')
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar')
plt.title('Top 10 Products by Sales')
plt.ylabel('Sales')
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Month'] = df['Order Date'].dt.to_period('M')

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(figsize=(12,5))
plt.title('Monthly Sales Trend')
plt.ylabel('Sales')
plt.show()

# %%
import pandas as pd

# Load Dataset
df = pd.read_csv("Global_Superstore2.csv", encoding="latin1")

# Check Missing Values
print(df.isnull().sum())

# Handle Missing Values
df['Postal Code'] = df['Postal Code'].fillna('Unknown')

# Check Duplicate Rows
print("Duplicate Rows:", df.duplicated().sum())

# Remove Duplicates
df.drop_duplicates(inplace=True)

# Convert Data Types
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# Export Cleaned Dataset
df.to_csv('Global_Superstore_Cleaned.csv', index=False)

print("Data cleaning completed successfully!")
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64
# Duplicate Rows: 0
# Data cleaning completed successfully!

# %%
import os
'Global_Superstore_Cleaned.csv' in os.listdir()
# Out:
# True

# %%
import os

print(os.path.abspath('Global_Superstore_Cleaned.csv'))
# Out:
# C:\Users\hp\Global_Superstore_Cleaned.csv
